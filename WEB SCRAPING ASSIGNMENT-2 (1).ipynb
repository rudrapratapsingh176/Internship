# %%
# !pip install selenium
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: selenium in c:\users\rudra\appdata\roaming\python\python39\site-packages (4.7.2)
# Requirement already satisfied: certifi>=2021.10.8 in c:\programdata\anaconda3\lib\site-packages (from selenium) (2021.10.8)
# Requirement already satisfied: trio~=0.17 in c:\users\rudra\appdata\roaming\python\python39\site-packages (from selenium) (0.22.0)
# Requirement already satisfied: urllib3[socks]~=1.26 in c:\programdata\anaconda3\lib\site-packages (from selenium) (1.26.9)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\rudra\appdata\roaming\python\python39\site-packages (from selenium) (0.9.2)
# Requirement already satisfied: sniffio in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: sortedcontainers in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: async-generator>=1.9 in c:\users\rudra\appdata\roaming\python\python39\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: attrs>=19.2.0 in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium) (21.4.0)
# Requirement already satisfied: idna in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.3)
# Requirement already satisfied: outcome in c:\users\rudra\appdata\roaming\python\python39\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in c:\users\rudra\appdata\roaming\python\python39\site-packages (from trio~=0.17->selenium) (1.1.0)
# Requirement already satisfied: cffi>=1.14 in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.0)
# Requirement already satisfied: pycparser in c:\programdata\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: wsproto>=0.14 in c:\users\rudra\appdata\roaming\python\python39\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\programdata\anaconda3\lib\site-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\rudra\appdata\roaming\python\python39\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %%
import selenium
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
import pandas as pd

# %%
driver=webdriver.Chrome(r"C:\Users\rudra\Downloads\chromedriver_win32\chromedriver.exe")
# Out:
# C:\Users\rudra\AppData\Local\Temp\ipykernel_8936\3679002656.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r"C:\Users\rudra\Downloads\chromedriver_win32\chromedriver.exe")

# %%
driver.get("https://www.naukri.com/")

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
Designations=driver.find_element(By.CLASS_NAME,"suggestor-input ")
Designations.send_keys('Data Analyst')

# %%
location=driver.find_element(By.XPATH,'/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input')
location.send_keys('Bangalore')

# %%
search=driver.find_element(By.XPATH,'/html/body/div[1]/div[6]/div/div/div[6]')
search.click()

# %%
job_title=[]
job_location=[]
company_name=[]
experience_required=[]

# %%
title=driver.find_elements(By.XPATH,'//a[@class="title ellipsis"]')
for i in title[0:10]:
    title1=i.text
    job_title.append(title1)

# %%
loaction=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft locWdth"]')
for i in loaction[0:10]:
    location1=i.text
    job_location.append(location1)

# %%
company=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company[0:10]:
    company1=i.text
    company_name.append(company1)

# %%
experience=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft expwdth"]')
for i in experience[0:10]:
    experience1=i.text
    experience_required.append(experience1)

# %%
import pandas as pd

# %%
print(len(experience_required),len(company_name),len(job_location),len(job_title))
# Out:
# 10 10 10 10

# %%
df=pd.DataFrame({'Title':job_title,'Location':job_location,'Company':company_name,'Experience':experience_required})
df
# Out:
#                                                Title  \
# 0         Data Analyst/Senior Analyst - R/SQL/Python
# 1                                       Data Analyst
# 2  data analyst / data analytics - US MNC (analyt...
# 3      Business Data Analyst (Sr Exe / Asst Manager)
# 4   Junior Data Analyst/ Scientist- Fresher Position
# 5                                 Staff Data Analyst
# 6                             Reference Data Analyst
# 7            Data Analysts - Compliance Surveillance
# 8                                    Sr Data Analyst
# 9  Job Opportunity with Leading MNC - Senior Data...
#
#                                             Location  \
# 0  Temp. WFH - Bangalore/Bengaluru, Kolkata, Mumb...
# 1                                Bangalore/Bengaluru
# 2  Temp. WFH - Bangalore/Bengaluru, Gurgaon/Gurugram
# 3                                Bangalore/Bengaluru
# 4  Hybrid - Bangalore/Bengaluru, New Delhi, Mumba...
# 5                                Bangalore/Bengaluru
# 6                                Bangalore/Bengaluru
# 7                       Hybrid - Bangalore/Bengaluru
# 8                       Hybrid - Bangalore/Bengaluru
# 9                                Bangalore/Bengaluru
#
#                                   Company Experience
# 0                 The Nikharv Consultancy    3-6 Yrs
# 1                                  Target    2-4 Yrs
# 2                      Aspyra Hr Services    3-8 Yrs
# 3                             Talentleads    3-5 Yrs
# 4                    Sejal Consulting Hub    0-5 Yrs
# 5                                 Walmart  10-14 Yrs
# 6                           Deutsche Bank    6-8 Yrs
# 7                 Standard Chartered Bank    4-9 Yrs
# 8                            Amolitalents    6-9 Yrs
# 9  Enrich And Enlight Business Consulting    5-7 Yrs

# %%
driver=webdriver.Chrome(r"C:\Users\rudra\Downloads\chromedriver_win32\chromedriver.exe")
driver.get("https://www.naukri.com/")

# %%
Designations=driver.find_element(By.CLASS_NAME,"suggestor-input ")
Designations.send_keys('Data Scientist')

# %%
location=driver.find_element(By.XPATH,'/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input')
location.send_keys('Bangalore')

# %%
search=driver.find_element(By.XPATH,'/html/body/div[1]/div[6]/div/div/div[6]')
search.click()

# %%
job_title=[]
job_location=[]
company_name=[]
experience_required=[]

# %%
title=driver.find_elements(By.XPATH,'//a[@class="title ellipsis"]')
for i in title[0:10]:
    title1=i.text
    job_title.append(title1)

# %%
loaction=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft locWdth"]')
for i in loaction[0:10]:
    location1=i.text
    job_location.append(location1)

# %%
company=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company[0:10]:
    company1=i.text
    company_name.append(company1)

# %%
experience=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft expwdth"]')
for i in experience[0:10]:
    experience1=i.text
    experience_required.append(experience1)

# %%
print(len(experience_required),len(company_name),len(job_location),len(job_title))
# Out:
# 10 10 10 10

# %%
df=pd.DataFrame({'Title':job_title,'Location':job_location,'Company':company_name,'Experience':experience_required})
df
# Out:
#                               Title  \
# 0                    Data Scientist
# 1                    Data Scientist
# 2           Data Science Specialist
# 3  Analystics & Modeling Specialist
# 4               Lead Data Scientist
# 5                    Data Scientist
# 6                    Data Scientist
# 7                Staff Data Analyst
# 8                    Data Scientist
# 9    Data Scientist Knowledge graph
#
#                                             Location        Company Experience
# 0  Bangalore/Bengaluru, Noida, Kolkata, Mumbai, H...      Capgemini   9-14 Yrs
# 1  Temp. WFH - Bangalore/Bengaluru, Hyderabad/Sec...  Tech Mahindra   7-12 Yrs
# 2  Bangalore/Bengaluru, Kolkata, Mumbai, Hyderaba...      Accenture    2-4 Yrs
# 3  Bangalore/Bengaluru, Kolkata, Mumbai, Hyderaba...      Accenture    6-8 Yrs
# 4  Bangalore/Bengaluru, Noida, Hyderabad/Secunder...      Birlasoft   8-12 Yrs
# 5  Hybrid - Bangalore/Bengaluru, Noida, Hyderabad...      Birlasoft   8-12 Yrs
# 6                                Bangalore/Bengaluru            ANZ    2-6 Yrs
# 7                                Bangalore/Bengaluru        Walmart  10-14 Yrs
# 8                                Bangalore/Bengaluru            ANZ    2-7 Yrs
# 9                 Hybrid - Bangalore/Bengaluru, Pune          Capco   7-12 Yrs

# %%
driver=webdriver.Chrome(r"C:\Users\rudra\Downloads\chromedriver_win32\chromedriver.exe")
driver.get("https://www.naukri.com/")

# %%
Designation=driver.find_element(By.XPATH,'/html/body/div[1]/div[6]/div/div/div[1]/div/div/div/input')
Designation.send_keys('Data Scientist')

# %%
Location=driver.find_element(By.XPATH,'/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input')
Location.send_keys('Delhi / NCR')

# %%
Search=driver.find_element(By.XPATH,'/html/body/div[1]/div[6]/div/div/div[6]')
Search.click()

# %%
Salary=driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/div/div/section[1]/div[2]/div[6]/div[2]/div[2]')
Salary.click()

# %%
job_title=[]
job_location=[]
company_name=[]
experience_required=[]

# %%
title=driver.find_elements(By.XPATH,'//a[@class="title ellipsis"]')
for i in title[0:10]:
    title1=i.text
    job_title.append(title1)

# %%
loaction=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft locWdth"]')
for i in loaction[0:10]:
    location1=i.text
    job_location.append(location1)

# %%
company=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company[0:10]:
    company1=i.text
    company_name.append(company1)

# %%
experience=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft expwdth"]')
for i in experience[0:10]:
    experience1=i.text
    experience_required.append(experience1)

# %%
print(len(experience_required),len(company_name),len(job_location),len(job_title))
# Out:
# 10 10 10 10

# %%
df=pd.DataFrame({'Title':job_title,'Location':job_location,'Company':company_name,'Experience':experience_required})
df
# Out:
#                                                Title  \
# 0                                 Staff Data Analyst
# 1  Job | Hiring For AVP/ VP | Senior Data Scienti...
# 2                      Data Science - Technical Lead
# 3            Data Science - Senior Software Engineer
# 4                                     Data Scientist
# 5                 Data Science - Engineering Manager
# 6                 Hiring Data Scientist // Bangalore
# 7                           Analyst - Data Scientist
# 8                        Specialist - Data Scientist
# 9                    ML Workflow Engineering Manager
#
#                                             Location           Company  \
# 0                                Bangalore/Bengaluru           Walmart
# 1  Hybrid - Pune, Gurgaon/Gurugram, Bangalore/Ben...  Citicorp Finance
# 2                         Noida, Bangalore/Bengaluru             Paytm
# 3                         Noida, Bangalore/Bengaluru             Paytm
# 4                                Bangalore/Bengaluru       UPL Limited
# 5                     New Delhi, Bangalore/Bengaluru             Paytm
# 6                       Hybrid - Bangalore/Bengaluru          Randstad
# 7                                             Mumbai       UPL Limited
# 8                                             Mumbai       UPL Limited
# 9                                             Mumbai            Pfizer
#
#   Experience
# 0  10-14 Yrs
# 1   8-13 Yrs
# 2    6-8 Yrs
# 3    3-6 Yrs
# 4    3-7 Yrs
# 5    3-5 Yrs
# 6    2-5 Yrs
# 7    2-3 Yrs
# 8    7-9 Yrs
# 9    5-8 Yrs

# %%
driver=webdriver.Chrome(r"C:\Users\rudra\Downloads\chromedriver_win32\chromedriver.exe")
driver.get("https://www.flipkart.com/")

# %%
sun=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/div/input')
sun.send_keys('sunglasses')

# %%
Search=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/button')
Search.click()

# %%
Brand=[]
product_description=[]
price=[]

# %%
start=0
end=3
for page in range(start,end):
    brand=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
    for i in brand:
        brand1=i.text
        Brand.append(brand1)
    product=driver.find_elements(By.XPATH,'//div[@class="_1xHGtK _373qXS"]')
    for i in product:
        product1=i.text
        product_description.append(product1)
    Price=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
    for i in Price:
        price.append(i.text)    
    next_button=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[11]')
    next_button.click() 
    time.sleep(1)

# %%
print(len(Brand),len(product_description),len(price))
# Out:
# 120 120 120

# %%
df=pd.DataFrame({'Brand':Brand,'Product Description':product_description,'Price':price})[0:100]
df
# Out:
#         Brand                                Product Description Price
# 0      PIRASO  Ad\nPIRASO\nUV Protection Rectangular Sunglass...  ₹182
# 1      artrue  Ad\nartrue\nUV Protection, Riding Glasses, Pol...  ₹310
# 2    Fastrack  Fastrack\nUV Protection Wayfarer Sunglasses (F...  ₹599
# 3   Elligator  Bestseller\nElligator\nUV Protection Cat-eye, ...  ₹149
# 4    Fastrack  Fastrack\nUV Protection Rectangular Sunglasses...  ₹499
# ..        ...                                                ...   ...
# 95     PIRASO  Ad\nPIRASO\nPolarized Wrap-around Sunglasses (...  ₹397
# 96      NuVew  NuVew\nUV Protection, Gradient Aviator Sunglas...  ₹125
# 97     AISLIN  AISLIN\nToughened Glass Lens, UV Protection Av...  ₹705
# 98     AISLIN  AISLIN\nUV Protection, Gradient Butterfly, Ret...  ₹498
# 99     PIRASO  Ad\nPIRASO\nUV Protection Butterfly Sunglasses...  ₹316
#
# [100 rows x 3 columns]

# %%
driver=webdriver.Chrome(r"C:\Users\rudra\Downloads\chromedriver_win32\chromedriver.exe")
driver.get("https://www.flipkart.com/apple-iphone-11-black-64-gb-includes-earpods-power-adapter/product-reviews/itm0f37c2240b217?pid=MOBFKCTSVZAXUHGR&lid=LSTMOBFKCTSVZAXUHGREPBFGI&marketplace=FLIPKART")

# %%
Rating=[]
Review_summary=[]
Full_review=[]

# %%
Rating1=[]
Rating2=[]

# %%
start=0
end=10
for page in range(start,end):
    rating=driver.find_elements(By.XPATH,'//div[@class="_3LWZlK _1BLPMq"]')
    for i in rating:
        Rating1.append(i.text)
    rating=driver.find_elements(By.XPATH,'//div[@class="_3LWZlK _1rdVr6 _1BLPMq"]')
    for i in rating:
        Rating2.append(i.text)    
    review=driver.find_elements(By.XPATH,'//p[@class="_2-N8zT"]')
    for i in review:
        Review_summary.append(i.text)    
    full=driver.find_elements(By.XPATH,'//div[@class="t-ZTKy"]')
    for i in full:
        Full_review.append(i.text)
    rating=driver.find_elements(By.XPATH,'//div[@class="_3LWZlK _1rdVr6 _1BLPMq"]')
    for i in rating:
        Rating2.append(i.text)    
    next_button=driver.find_element(By.XPATH,'/html/body/div/div/div[3]/div/div/div[2]/div[13]/div/div/nav/a[11]')
    next_button.click() 
    time.sleep(1)

# %%
Rating=Rating1+Rating2

# %%
print(len(Rating),len(Review_summary),len(Full_review))
# Out:
# 100 100 100

# %%
df=pd.DataFrame({'Rating':Rating,'Review_summary':Review_summary,'Full_review':Full_review})
df
# Out:
#    Rating       Review_summary  \
# 0       5       Simply awesome
# 1       5     Perfect product!
# 2       5  Best in the market!
# 3       4      Value-for-money
# 4       5   Highly recommended
# ..    ...                  ...
# 95      5             Terrific
# 96      5             Fabulous
# 97      4  Best in the market!
# 98      1       Simply awesome
# 99      1      Worth the money
#
#                                           Full_review
# 0   Really satisfied with the Product I received.....
# 1   Amazing phone with great cameras and better ba...
# 2   Great iPhone very snappy experience as apple k...
# 3   I'm Really happy with the product\nDelivery wa...
# 4   It's my first time to use iOS phone and I am l...
# ..                                                ...
# 95  Flipkart delivered in 24 hrs in a well package...
# 96  Its the best product that person already in ap...
# 97  Phone is good. 1st tym on iOS. Enjoying it til...
# 98  Nice but the price will keep outstanding for e...
# 99  Overall the phone is great.\nJust the battery ...
#
# [100 rows x 3 columns]

# %%
driver=webdriver.Chrome(r"C:\Users\rudra\Downloads\chromedriver_win32\chromedriver.exe")
driver.get("https://www.flipkart.com/")

# %%
shoes=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/div/input')
shoes.send_keys('sneakers')

# %%
search=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/button')
search.click()

# %%
Brand=[]
Product_Description=[]
Price=[]

# %%
start=0
end=3
for page in range(start,end):
    brand=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
    for i in brand:
        brand1=i.text
        Brand.append(brand1)
    product=driver.find_elements(By.XPATH,'//div[@class="_1xHGtK _373qXS"]')
    for i in product:
        product1=i.text
        Product_Description.append(product1)
    price=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
    for i in price:
        price1=i.text
        Price.append(price1)    
    next_button=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[11]')
    next_button.click() 
    time.sleep(1)

# %%
print(len(Brand),len(Product_Description),len(Price))
# Out:
# 120 120 120

# %%
df=pd.DataFrame({'Brand':Brand,'Product_Description':Product_Description,'Price':Price})[0:100]
df
# Out:
#                   Brand                                Product_Description  \
# 0        KNIGHT WALKERS  Ad\nKNIGHT WALKERS\nSneakers For Men\n₹614₹1,4...
# 1                   GVR  Ad\nGVR\nSNEAKERS FOR MEN Sneakers For Men\n₹7...
# 2   World Wear Footwear  World Wear Footwear\n5011-Latest Collection St...
# 3                  aadi  aadi\nSynthetic Leather |Lightweight|Comfort|S...
# 4                ADIDAS  ADIDAS\nSTREET ICON M Sneakers For Men\n₹1,943...
# ..                  ...                                                ...
# 95               Eather  Ad\nEather\nSneakers For Men\n₹499₹1,49966% of...
# 96             WOODLAND  WOODLAND\nSneakers For Men\n₹1,946₹2,99535% of...
# 97       Mast & Harbour  Mast & Harbour\nSneakers For Men\n₹599₹2,39975...
# 98               Kraasa  Kraasa\nSneakers For Women\n₹299₹99970% off\nF...
# 99               Eather  Ad\nEather\nSneakers For Men\n₹599₹1,49960% of...
#
#      Price
# 0     ₹614
# 1     ₹749
# 2     ₹399
# 3     ₹434
# 4   ₹1,943
# ..     ...
# 95    ₹499
# 96  ₹1,946
# 97    ₹599
# 98    ₹299
# 99    ₹599
#
# [100 rows x 3 columns]

# %%
driver=webdriver.Chrome(r"C:\Users\rudra\Downloads\chromedriver_win32\chromedriver.exe")
driver.get("https://www.amazon.in/")

# %%
laptop=driver.find_element(By.XPATH,'/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[2]/div[1]/input')
laptop.send_keys('Laptop')

# %%
search=driver.find_element(By.XPATH,'/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div/span/input')
search.click()

# %%
cpu=driver.find_element(By.XPATH,'/html/body/div[1]/div[2]/div[1]/div[2]/div/div[3]/span/div[1]/div/div/div[6]/ul[6]/li[14]/span/a')
cpu.click()

# %%
Title=[]
Rating=[]
Price=[]

# %%
    title=driver.find_elements(By.XPATH,'//h2[@class="a-size-mini a-spacing-none a-color-base s-line-clamp-2"]')
    for i in title[0:18]:
        title1=i.text
        Title.append(title1)
    title=driver.find_elements(By.XPATH,'//span[@class="a-icon-alt"]')
    for i in title[0:18]:
        title1=i.text
        Rating.append(title1)
        title=driver.find_elements(By.XPATH,'//span[@class="a-price-whole"]')
    for i in title[0:18]:
        title1=i.text
        Price.append(title1)

# %%
df=pd.DataFrame({'Title':Title,'Rating':Rating,'Price':Price})
df.drop([5,6,7,8,9,10,11,12],axis=0,inplace=True)
df
# Out:
#                                                 Title Rating     Price
# 0   LG Gram17 Intel EVO-[12th Gen Core i7/Win11/16...         1,15,999
# 1   LG Gram14 Intel EVO-[12th Gen Corei7/Win11/16G...           84,500
# 2   ASUS Vivobook 14, Intel Core i7-1165G7 11th Ge...           56,990
# 3   Acer Nitro 5 Gaming Laptop Intel core i7 11th ...           78,106
# 4   Lenovo IdeaPad Slim 5 12th Gen Intel Core i7 1...           79,990
# 13  ASUS TUF Gaming F15 (2022), 15.6"(39.62 cms) F...           94,990
# 14  Fujitsu UH-X 11th Gen Intel Core i7 13.3" FHD ...           94,990
# 15  Samsung Galaxy Book2 Pro Intel 12th Gen i7 Evo...         1,09,990
# 16  Fujitsu UH-X 11th Gen Intel Core i7 13.3" FHD ...           94,990
# 17  Lenovo ThinkPad P14s Mobile Workstation 11th G...         1,03,990

# %%
driver=webdriver.Chrome(r"C:\Users\rudra\Downloads\chromedriver_win32\chromedriver.exe")
driver.get("https://www.azquotes.com/")

# %%
top_quotes=driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/div[1]/div/div[3]/ul/li[5]/a')
top_quotes.click()

# %%
Quotes=[]
Author=[]
Type_Of_Quotes=[]

# %%
start=0
end=10
for page in range(start,end):
    a=driver.find_elements(By.XPATH,'//a[@class="title"]')
    for i in a:
        a1=i.text
        Quotes.append(a1)
    a=driver.find_elements(By.XPATH,'//div[@class="author"]')
    for i in a:
        a1=i.text
        Author.append(a1)
    a=driver.find_elements(By.XPATH,'//div[@class="tags"]')
    for i in a:
        a1=i.text
        Type_Of_Quotes.append(a1)    
    next_button=driver.find_element(By.XPATH,'/html/body/div[1]/div[2]/div/div/div/div[1]/div/div[4]/li[12]/a')
    next_button.click() 
    time.sleep(1)

# %%
df=pd.DataFrame({'Quote':Quotes,'Author':Author,'Type_Of_Quotes':Type_Of_Quotes})
df
# Out:
#                                                  Quote              Author  \
# 0    The essence of strategy is choosing what not t...      Michael Porter
# 1    One cannot and must not try to erase the past ...          Golda Meir
# 2    Patriotism means to stand by the country. It d...  Theodore Roosevelt
# 3    Death is something inevitable. When a man has ...      Nelson Mandela
# 4    You have to love a nation that celebrates its ...        Erma Bombeck
# ..                                                 ...                 ...
# 995  Regret for the things we did can be tempered b...    Sydney J. Harris
# 996  America... just a nation of two hundred millio...  Hunter S. Thompson
# 997  For every disciplined effort there is a multip...            Jim Rohn
# 998  The spiritual journey is individual, highly pe...            Ram Dass
# 999  The mind is not a vessel to be filled but a fi...            Plutarch
#
#                                Type_Of_Quotes
# 0    Essence, Deep Thought, Transcendentalism
# 1                   Inspiration, Past, Trying
# 2                         Country, Peace, War
# 3          Inspirational, Motivational, Death
# 4                4th Of July, Food, Patriotic
# ..                                        ...
# 995         Love, Inspirational, Motivational
# 996                    Gun, Two, Qualms About
# 997     Inspirational, Greatness, Best Effort
# 998                    Spiritual, Truth, Yoga
# 999      Inspirational, Leadership, Education
#
# [1000 rows x 3 columns]

# %%
driver=webdriver.Chrome(r"C:\Users\rudra\Downloads\chromedriver_win32\chromedriver.exe")
driver.get("https://www.jagranjosh.com/")
# Out:
# C:\Users\rudra\AppData\Local\Temp\ipykernel_7012\3958218933.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r"C:\Users\rudra\Downloads\chromedriver_win32\chromedriver.exe")

# %%
Gk=driver.find_element(By.XPATH,'/html/body/div/div[1]/div/div[1]/div/div[6]/div/div[1]/header/div[3]/ul/li[9]/a')
Gk.click()

# %%
news=driver.find_element(By.XPATH,'/html/body/div/div/div/div[2]/div/div[10]/div/div/ul/li[2]/a')
news.click()

# %%
Name=[]
Born_Dead=[]
Terms_of_office=[]
Remarks=[]

# %%
name1=[]
name2=[]
name3=[]
name4=[]
name5=[]

# %%
a=driver.find_elements(By.XPATH,'//td[@style="width: 150px; height: 121px;"]')
for i in a:
    a1=i.text
    name1.append(a1)
a=driver.find_elements(By.XPATH,'//td[@style="width: 150px; height: 80px;"]')
for i in a:
    a1=i.text
    name2.append(a1)
a=driver.find_elements(By.XPATH,'//td[@style="width: 150px; height: 104px;"]')
for i in a:
    a1=i.text
    name3.append(a1)
a=driver.find_elements(By.XPATH,'//td[@style="width: 150px; height: 87px;"]')
for i in a:
    a1=i.text
    name4.append(a1)
a=driver.find_elements(By.XPATH,'//td[@style="width: 150px; height: 97px;"]')
for i in a:
    a1=i.text
    name5.append(a1)

# %%
Name=name1+name2+name3+name4+name5

# %%
Born_Dead1=[]
Born_Dead2=[]
Born_Dead3=[]
Born_Dead4=[]
Born_Dead5=[]

# %%
a=driver.find_elements(By.XPATH,'//td[@style="width: 105px; height: 121px;"]')
for i in a:
    a1=i.text
    Born_Dead1.append(a1)
a=driver.find_elements(By.XPATH,'//td[@style="width: 105px; height: 80px;"]')
for i in a:
    a1=i.text
    Born_Dead2.append(a1) 
a=driver.find_elements(By.XPATH,'//td[@style="width: 105px; height: 104px;"]')
for i in a:
    a1=i.text
    Born_Dead3.append(a1) 
a=driver.find_elements(By.XPATH,'//td[@style="width: 105px; height: 87px;"]')
for i in a:
    a1=i.text
    Born_Dead4.append(a1)
a=driver.find_elements(By.XPATH,'//td[@style="width: 105px; height: 97px;"]')
for i in a:
    a1=i.text
    Born_Dead5.append(a1)

# %%
Born_Dead=Born_Dead1+Born_Dead2+Born_Dead3+Born_Dead4+Born_Dead5

# %%
Terms_of_office1=[]
Terms_of_office2=[]
Terms_of_office3=[]
Terms_of_office4=[]
Terms_of_office5=[]

# %%
a=driver.find_elements(By.XPATH,'//td[@style="width: 256px; height: 121px;"]')
for i in a:
    a1=i.text
    Terms_of_office1.append(a1)
a=driver.find_elements(By.XPATH,'//td[@style="width: 256px; height: 80px;"]')
for i in a:
    a1=i.text
    Terms_of_office2.append(a1)
a=driver.find_elements(By.XPATH,'//td[@style="width: 256px; height: 104px;"]')
for i in a:
    a1=i.text
    Terms_of_office3.append(a1)   
a=driver.find_elements(By.XPATH,'//td[@style="width: 256px; height: 87px;"]')
for i in a:
    a1=i.text
    Terms_of_office4.append(a1)
a=driver.find_elements(By.XPATH,'//td[@style="width: 256px; height: 97px;"]')
for i in a:
    a1=i.text
    Terms_of_office5.append(a1)

# %%
Terms_of_office=Terms_of_office1+Terms_of_office2+Terms_of_office3+Terms_of_office4+Terms_of_office5

# %%
Remarks1=[]
Remarks2=[]
Remarks3=[]
Remarks4=[]
Remarks5=[]

# %%
a=driver.find_elements(By.XPATH,'//td[@style="width: 145px; height: 121px;"]')
for i in a:
    a1=i.text
    Remarks1.append(a1)
a=driver.find_elements(By.XPATH,'//td[@style="width: 145px; height: 80px;"]')
for i in a:
    a1=i.text
    Remarks2.append(a1)
a=driver.find_elements(By.XPATH,'//td[@style="width: 145px; height: 104px;"]')
for i in a:
    a1=i.text
    Remarks3.append(a1)
a=driver.find_elements(By.XPATH,'//td[@style="width: 145px; height: 87px;"]')
for i in a:
    a1=i.text
    Remarks4.append(a1)
a=driver.find_elements(By.XPATH,'//td[@style="width: 145px; height: 97px;"]')
for i in a:
    a1=i.text
    Remarks5.append(a1)

# %%
Remarks=Remarks1+Remarks2+Remarks3+Remarks4+Remarks5

# %%
df=pd.DataFrame({'Name':Name,'Born-Dead':Born_Dead,'Terms_of_office':Terms_of_office,'Remarks':Remarks})
df.sort_values(by="Born-Dead")
# Out:
#                            Name     Born-Dead  \
# 0             Jawahar Lal Nehru   (1889–1964)
# 12                Morarji Desai   (1896–1995)
# 2     Gulzarilal Nanda (Acting)   (1898-1998)
# 3   Gulzari Lal Nanda  (Acting)   (1898-1998)
# 5                  Charan Singh   (1902–1987)
# 1           Lal Bahadur Shastri   (1904–1966)
# 4                 Indira Gandhi   (1917–1984)
# 15                Indira Gandhi   (1917–1984)
# 10           Inder Kumar Gujral   (1919–2012)
# 7           P. V. Narasimha Rao   (1921–2004)
# 8          Atal Bihari Vajpayee  (1924- 2018)
# 13         Atal Bihari Vajpayee   (1924-2018)
# 16              Chandra Shekhar   (1927–2007)
# 17                  V. P. Singh   (1931–2008)
# 6                  Rajiv Gandhi   (1944–1991)
# 11               Manmohan Singh   (born 1932)
# 9              H. D. Deve Gowda   (born 1933)
# 14                Narendra Modi   (born 1950)
#
#                                       Terms_of_office  \
# 0   15 August 1947 to 27 May 1964\n16 years, 286 days
# 12  24 March 1977 to  28 July 1979 \n2 year, 126 days
# 2                27 May 1964 to 9 June 1964,\n13 days
# 3         11 January 1966 to 24 January 1966\n13 days
# 5           28 July 1979 to 14 January 1980\n170 days
# 1    9 June 1964 to 11 January 1966\n1 year, 216 days
# 4   24 January 1966 to 24 March 1977\n11 years, 59...
# 15  14 January 1980 to 31 October 1984\n4 years, 2...
# 10          21 April 1997 to 19 March 1998 \n332 days
# 7      21 June 1991 to 16 May 1996\n4 years, 330 days
# 8                 16 May 1996 to 1 June 1996\n16 days
# 13    19 March 1998 to 22 May 2004 \n6 years, 64 days
# 16         10 November 1990 to 21 June 1991\n223 days
# 17      2 December 1989 to 10 November 1990\n343 days
# 6   31 October 1984 to 2 December 1989\n5 years, 3...
# 11    22 May 2004 to 26 May 2014   \n10 years, 4 days
# 9              1 June 1996 to 21 April 1997\n324 days
# 14                              26 May 2014 - Present
#
#                                               Remarks
# 0   The first prime minister of India and the long...
# 12  Oldest to become PM (81 years old) and first t...
# 2                            First acting PM of India
# 3                                                   -
# 5             Only PM who did not face the Parliament
# 1   He has given the slogan of 'Jai Jawan Jai Kisa...
# 4                First female Prime Minister of India
# 15  The first lady who served as PM for the second...
# 10                                             ------
# 7                           First PM from south India
# 8                              PM for shortest tenure
# 13   The first non-congress PM who completed a ful...
# 16              He belongs to  Samajwadi Janata Party
# 17  First PM to step down after a vote of no confi...
# 6                Youngest to become PM (40 years old)
# 11                                      First Sikh PM
# 9                           He belongs to  Janata Dal
# 14  4th Prime Minister of India who served two con...

# %%
driver=webdriver.Chrome(r"C:\Users\rudra\Downloads\chromedriver_win32\chromedriver.exe")
driver.get("https://www.motor1.com/")
# Out:
# C:\Users\rudra\AppData\Local\Temp\ipykernel_15492\1899407209.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r"C:\Users\rudra\Downloads\chromedriver_win32\chromedriver.exe")

# %%
menu=driver.find_element(By.XPATH,'/html/body/div[3]/div[2]/div/div/div[1]/div')
menu.click()

# %%
feature=driver.find_element(By.XPATH,'/html/body/div[4]/div[1]/div[3]/ul/li[5]/a')
feature.click()

# %%
view=driver.find_element(By.XPATH,'/html/body/div[3]/div[7]/div/div[1]/div[2]/a')
view.click()

# %%
lists=driver.find_element(By.XPATH,'/html/body/div[3]/div[9]/div[1]/div[1]/div/div/div[9]/div/div[1]/h3/a')
lists.click()

# %%
name=[]
price=[]

# %%
a=driver.find_elements(By.XPATH,'//h3[@class="subheader"]')
for i in a[0:50]:
    a1=i.text
    name.append(a1)
a=driver.find_elements(By.XPATH,"//strong")
for i in a[0:50]:
    a1=i.text
    price.append(a1)

# %%
df=pd.DataFrame({'Car name':name,'Price':price})
df
# Out:
#                            Car name                 Price
# 0                         Drako GTE   Price: $1.2 Million
# 1                     De Tomaso P72   Price: $1.3 Million
# 2                 Ferrari LaFerrari   Price: $1.4 Million
# 3                     Pagani Huayra   Price: $1.4 Million
# 4                      McLaren Elva
# 5                       Czinger 21C   Price: $1.7 Million
# 6                     Ferrari Monza   Price: $1.7 Million
# 7                Gordon Murray T.33   Price: $1.7 Million
# 8                 Koenigsegg Gemera   Price: $1.7 Million
# 9                       Zenvo TSR-S   Price: $1.7 Million
# 10               Hennessey Venom F5   Price: $1.7 Million
# 11                  Bentley Bacalar   Price: $1.8 Million
# 12    Hispano Suiza Carmen Boulogne   Price: $1.9 Million
# 13           Bentley Mulliner Batur   Price: $1.9 Million
# 14                     Deus Vayanne   Price: $2.0 Million
# 15                      SSC Tuatara   Price: $2.0 Million
# 16                      Lotus Evija  Price: $2.0 Million*
# 17              Aston Martin Vulcan   Price: $2.1 Million
# 18                       Delage D12   Price: $2.3 Million
# 19                McLaren Speedtail   Price: $2.3 Million
# 20                     Rimac Nevera   Price: $2.3 Million
# 21                    Pagani Utopia   Price: $2.4 Million
# 22             Pininfarina Battista   Price: $2.5 Million
# 23                Ferrari FXX K Evo   Price: $2.5 Million
# 24               Gordon Murray T.50   Price: $2.6 Million
# 25             Lamborghini Countach   Price: $2.6 Million
# 26         Mercedes-AMG Project One   Price: $2.6 Million
# 27              Aston Martin Victor   Price: $2.7 Million
# 28      Hennessey Venom F5 Roadster   Price: $3.0 Million
# 29                 Koenigsegg Jesko          $3.0 Million
# 30            Aston Martin Valkyrie   Price: $3.0 Million
# 31        W Motors Lykan Hypersport   Price: $3.2 Million
# 32                    McLaren Solus   Price: $3.4 Million
# 33        Pagani Huayra Roadster BC          $3.5 Million
# 34         Bugatti Chiron Pur Sport   Price: $3.5 Million
# 35                 Lamborghini Sian   Price: $3.6 Million
# 36                 Koenigsegg CC850   Price: $3.6 million
# 37  Bugatti Chiron Super Sport 300+   Price: $3.7 Million
# 38               Lamborghini Veneno   Price: $3.9 Million
# 39                   Bugatti Bolide   Price: $4.5 Million
# 40                  Bugatti Mistral   Price: $4.7 Million
# 41              Pagani Huayra Imola   Price: $5.0 Million
# 42                     Bugatti Divo   Price: $5.4 Million
# 43              SP Automotive Chaos   Price: $5.8 Million
# 44                 Pagani Codalunga   Price: $6.4 Million
# 45         Mercedes-Maybach Exelero   Price: $7.4 Million
# 46               Bugatti Centodieci   Price: $8.0 Million
# 47             Rolls-Royce Sweptail   Price: $9.0 Million
# 48         Bugatti La Voiture Noire  Price: $12.8 Million
# 49           Rolls-Royce Boat Tail*  Price: $13.4 Million
